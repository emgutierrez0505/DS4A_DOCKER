# %%
# Initialize estimados_de_exito by everycountry
estimados_de_exito = {
'Australia': [0.6, 0.33, 0.11, 0.14],
'France': [0.66, 0.78, 0.98, 0.2],
'Italy': [0.6],
'Brazil': [0.22, 0.22, 0.43],
'USA': [0.2, 0.5, 0.3],
'England': [0.45],
'Canada': [0.25, 0.3],
'Argentina': [0.22],
'Greece': [0.45, 0.66, 0.75, 0.99, 0.15, 0.66],
'Morocco': [0.29],
'Tunisia': [0.68, 0.56],
'Egypt': [0.99],
'Jamaica': [0.61, 0.65, 0.71],
'Switzerland': [0.73, 0.86, 0.84, 0.51, 0.99],
'Germany': [0.45, 0.49, 0.36]
}

print (estimados_de_exito)
estimados_de_exito.keys()
list(estimados_de_exito.keys())
list(estimados_de_exito.values())

print('Comprobando si la llave de Marruecos (morocco) está presente:')
print('Morocco' in estimados_de_exito) #if 'Morocco' is in estimados_de_exito then it print true or false,

print('Comprobación de la presencia de la llave de Japón:')
japan_boolean = 'Japan' in estimados_de_exito
print(japan_boolean) # In this example, we use japan_boolean variable and write the result.

estimados_de_exito['Jamaica'] #Access to list for a key on type
lista_de_jamaica = estimados_de_exito['Jamaica'] #save the content list in a variable
print(lista_de_jamaica) 

print(lista_de_jamaica[0]) # Print the element 0 in the list lista_jamaica
print(lista_de_jamaica[1]) # Print the element 1 in the list lista_jamaica
print(lista_de_jamaica[2]) # Print the element 2 in the list lista_jamaica

print(lista_de_jamaica[-2:]) #(Go from the penultimate to the last)
print(lista_de_jamaica[1:]) #(Go from the second to the last)
print(estimados_de_exito['Jamaica'][0]) #get the fist position of the Jamaica list

len(lista_de_jamaica) #get the length of a list

promedio_jamaica = (0.61 + 0.65 + 0.71) / 3  #get arithmetics average
print(promedio_jamaica)  

nombre_de_pais = 'Jamaica'
lista_de_jamaica = estimados_de_exito[nombre_de_pais] 
print(lista_de_jamaica)

promedio_jamaica = sum(lista_de_jamaica) / len(lista_de_jamaica) # calculate average with function aggregate
minimo_jamaica = min(lista_de_jamaica) # calculate the minimum with function aggregate
maximo_jamaica = max(lista_de_jamaica) # calculate the maximum with function aggregate

print("País:",nombre_de_pais,", Promedio:",promedio_jamaica)
print("País:",nombre_de_pais,", Mínimo:",minimo_jamaica)
print("País:",nombre_de_pais,", Máximo:",maximo_jamaica)

promedio_jamaica = round(sum(lista_de_jamaica) / len(lista_de_jamaica),2) # Use round to 2 digits
minimo_jamaica = round(min(lista_de_jamaica),2)
maximo_jamaica = round(max(lista_de_jamaica),2)
print("País:",nombre_de_pais,", Promedio:",promedio_jamaica)
print("País:",nombre_de_pais,", Mínimo:",minimo_jamaica)
print("País:",nombre_de_pais,", Máximo:",maximo_jamaica)
# Out:
# {'Australia': [0.6, 0.33, 0.11, 0.14], 'France': [0.66, 0.78, 0.98, 0.2], 'Italy': [0.6], 'Brazil': [0.22, 0.22, 0.43], 'USA': [0.2, 0.5, 0.3], 'England': [0.45], 'Canada': [0.25, 0.3], 'Argentina': [0.22], 'Greece': [0.45, 0.66, 0.75, 0.99, 0.15, 0.66], 'Morocco': [0.29], 'Tunisia': [0.68, 0.56], 'Egypt': [0.99], 'Jamaica': [0.61, 0.65, 0.71], 'Switzerland': [0.73, 0.86, 0.84, 0.51, 0.99], 'Germany': [0.45, 0.49, 0.36]}
# Comprobando si la llave de Marruecos (morocco) está presente:
# True
# Comprobación de la presencia de la llave de Japón:
# False
# [0.61, 0.65, 0.71]
# 0.61
# 0.65
# 0.71
# [0.65, 0.71]
# [0.65, 0.71]
# 0.61
# 0.6566666666666666
# [0.61, 0.65, 0.71]
# País: Jamaica , Promedio: 0.6566666666666666
# País: Jamaica , Mínimo: 0.61
# País: Jamaica , Máximo: 0.71
